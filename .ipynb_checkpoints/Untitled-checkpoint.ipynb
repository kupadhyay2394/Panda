# %%
import pandas as pd
import numpy as nm

# %%
dict1={
    "Name":["aka", "asa", "jls","sdj"],
    "marks":[12,54,65,74],
    "city":["gkp","lko","asn","asl"]
}

# %%
#data frame use as excel sheet
df=pd.DataFrame(dict1)

# %%
df
# Out:
#   Name  marks city
# 0  aka     12  gkp
# 1  asa     54  lko
# 2  jls     65  asn
# 3  sdj     74  asl

# %%
#to make a excell sheet
df.to_csv('hello.csv')

# %%
#to remove index
df.to_csv('hello1.csv',index=False)

# %%
#from stating
df.head(2)
# Out:
#   Name  marks city
# 0  aka     12  gkp
# 1  asa     54  lko

# %%
#from last
df.tail(2)
# Out:
#   Name  marks city
# 2  jls     65  asn
# 3  sdj     74  asl

# %%
#for statical analysis
df.describe()
# Out:
#           marks
# count   4.00000
# mean   51.25000
# std    27.41502
# min    12.00000
# 25%    43.50000
# 50%    59.50000
# 75%    67.25000
# max    74.00000

# %%
#series 1D array store row or col in dataframe
ser=pd.Series(nm.random.rand(34))

# %%
ser
# Out:
# 0     0.212841
# 1     0.717324
# 2     0.255128
# 3     0.223268
# 4     0.535405
# 5     0.787543
# 6     0.113241
# 7     0.649787
# 8     0.643668
# 9     0.400624
# 10    0.801069
# 11    0.946416
# 12    0.187068
# 13    0.113803
# 14    0.222566
# 15    0.486334
# 16    0.133811
# 17    0.879993
# 18    0.645824
# 19    0.738498
# 20    0.202130
# 21    0.649879
# 22    0.116784
# 23    0.105401
# 24    0.347863
# 25    0.279686
# 26    0.949660
# 27    0.906122
# 28    0.890615
# 29    0.498055
# 30    0.059157
# 31    0.838025
# 32    0.566887
# 33    0.020301
# dtype: float64

# %%
#dataframe is tabular spreadsheet store row and col
ndf=pd.DataFrame(nm.random.rand(234, 4))

# %%
ndf
# Out:
#             0         1         2         3
# 0    0.938852  0.077906  0.726501  0.821850
# 1    0.839622  0.847196  0.429198  0.091369
# 2    0.166745  0.904992  0.119703  0.984185
# 3    0.481827  0.013274  0.562768  0.928823
# 4    0.990852  0.148449  0.978093  0.744958
# ..        ...       ...       ...       ...
# 229  0.209921  0.955497  0.141425  0.671245
# 230  0.778924  0.642971  0.188551  0.590218
# 231  0.458433  0.165374  0.754682  0.516811
# 232  0.289907  0.398150  0.086080  0.669278
# 233  0.396148  0.104954  0.769315  0.954455
#
# [234 rows x 4 columns]

# %%
ndf[0][0]="hllo"

# %%
ndf
# Out:
#             0         1         2         3
# 0        hllo  0.077906  0.726501  0.821850
# 1    0.839622  0.847196  0.429198  0.091369
# 2    0.166745  0.904992  0.119703  0.984185
# 3    0.481827  0.013274  0.562768  0.928823
# 4    0.990852  0.148449  0.978093  0.744958
# ..        ...       ...       ...       ...
# 229  0.209921  0.955497  0.141425  0.671245
# 230  0.778924  0.642971  0.188551  0.590218
# 231  0.458433  0.165374  0.754682  0.516811
# 232  0.289907  0.398150  0.086080  0.669278
# 233  0.396148  0.104954  0.769315  0.954455
#
# [234 rows x 4 columns]

# %%
#to get index
ndf.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
#to get col
ndf.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# to get array of all data using numpy
ndf.to_numpy()
# Out:
# array([['hllo', 0.07790581761024606, 0.726501462227046,
#         0.8218500342520608],
#        [0.8396218765699291, 0.8471956474620607, 0.4291980144377997,
#         0.09136870940718445],
#        [0.16674539364369534, 0.9049917819423363, 0.11970251721759095,
#         0.984184975332277],
#        [0.4818267531640519, 0.013273863464252078, 0.5627684907348718,
#         0.9288231185309261],
#        [0.9908517967911626, 0.14844869304735397, 0.9780928153032775,
#         0.7449581384621026],
#        [0.7213547802403059, 0.8377995163968379, 0.3865972180859336,
#         0.814634643022643],
#        [0.36937554393823124, 0.6828974311795359, 0.28190324545760836,
#         0.4769468640420199],
#        [0.885267919360469, 0.5977939828095502, 0.8218657881408591,
#         0.39150486376679206],
#        [0.7554861453504129, 0.38403590341920635, 0.06573084072975655,
#         0.30239863403646594],
#        [0.7370553913631248, 0.3689224303698262, 0.30814842615640414,
# ...

# %%
#to trsanspose a matrix
ndf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0      hllo  0.839622  0.166745  0.481827  0.990852  0.721355  0.369376
# 1  0.077906  0.847196  0.904992  0.013274  0.148449    0.8378  0.682897
# 2  0.726501  0.429198  0.119703  0.562768  0.978093  0.386597  0.281903
# 3   0.82185  0.091369  0.984185  0.928823  0.744958  0.814635  0.476947
#
#         7         8         9    ...       224       225       226       227  \
# 0  0.885268  0.755486  0.737055  ...  0.043994  0.742042    0.8252   0.93889
# 1  0.597794  0.384036  0.368922  ...  0.397297   0.70959  0.482629  0.757868
# 2  0.821866  0.065731  0.308148  ...  0.690332  0.254754  0.075363   0.53923
# 3  0.391505  0.302399  0.860034  ...  0.837345  0.559454  0.799397  0.370963
#
#         228       229       230       231       232       233
# 0  0.868826  0.209921  0.778924  0.458433  0.289907  0.396148
# 1  0.938833  0.955497  0.642971  0.165374   0.39815  0.104954
# ...

# %%
# to sort use axis 1 for row and 0 for col
ndf.sort_index(axis=0, ascending=False)
# Out:
#             0         1         2         3
# 233  0.396148  0.104954  0.769315  0.954455
# 232  0.289907  0.398150  0.086080  0.669278
# 231  0.458433  0.165374  0.754682  0.516811
# 230  0.778924  0.642971  0.188551  0.590218
# 229  0.209921  0.955497  0.141425  0.671245
# ..        ...       ...       ...       ...
# 4    0.990852  0.148449  0.978093  0.744958
# 3    0.481827  0.013274  0.562768  0.928823
# 2    0.166745  0.904992  0.119703  0.984185
# 1    0.839622  0.847196  0.429198  0.091369
# 0        hllo  0.077906  0.726501  0.821850
#
# [234 rows x 4 columns]

# %%
#veiw make a new df which point to old df
ndf1=ndf

# %%
ndf1
# Out:
#             0         1         2         3
# 0        hllo  0.077906  0.726501  0.821850
# 1    0.839622  0.847196  0.429198  0.091369
# 2    0.166745  0.904992  0.119703  0.984185
# 3    0.481827  0.013274  0.562768  0.928823
# 4    0.990852  0.148449  0.978093  0.744958
# ..        ...       ...       ...       ...
# 229  0.209921  0.955497  0.141425  0.671245
# 230  0.778924  0.642971  0.188551  0.590218
# 231  0.458433  0.165374  0.754682  0.516811
# 232  0.289907  0.398150  0.086080  0.669278
# 233  0.396148  0.104954  0.769315  0.954455
#
# [234 rows x 4 columns]

# %%
ndf1[0][0]=56

# %%
ndf.head()
# Out:
#           0         1         2         3
# 0        56  0.077906  0.726501  0.821850
# 1  0.839622  0.847196  0.429198  0.091369
# 2  0.166745  0.904992  0.119703  0.984185
# 3  0.481827  0.013274  0.562768  0.928823
# 4  0.990852  0.148449  0.978093  0.744958

# %%
#copy make a another df same as old
ndf2=ndf.copy()

# %%
ndf2[0][0]=585
# Out:
# C:\Users\KRISHNAUPADHYAY\AppData\Local\Temp\ipykernel_7028\2754724001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf2[0][0]=585

# %%
ndf.head()
# Out:
#           0         1         2         3
# 0        56  0.077906  0.726501  0.821850
# 1  0.839622  0.847196  0.429198  0.091369
# 2  0.166745  0.904992  0.119703  0.984185
# 3  0.481827  0.013274  0.562768  0.928823
# 4  0.990852  0.148449  0.978093  0.744958

# %%
ndf2.head()
# Out:
#           0         1         2         3
# 0       585  0.077906  0.726501  0.821850
# 1  0.839622  0.847196  0.429198  0.091369
# 2  0.166745  0.904992  0.119703  0.984185
# 3  0.481827  0.013274  0.562768  0.928823
# 4  0.990852  0.148449  0.978093  0.744958

# %%
#use loc to change the value
ndf1.loc[1,2]=56.65

# %% [markdown]
# ndf2

# %%
ndf1
# Out:
#             0         1          2         3
# 0          56  0.077906   0.726501  0.821850
# 1    0.839622  0.847196  56.650000  0.091369
# 2    0.166745  0.904992   0.119703  0.984185
# 3    0.481827  0.013274   0.562768  0.928823
# 4    0.990852  0.148449   0.978093  0.744958
# ..        ...       ...        ...       ...
# 229  0.209921  0.955497   0.141425  0.671245
# 230  0.778924  0.642971   0.188551  0.590218
# 231  0.458433  0.165374   0.754682  0.516811
# 232  0.289907  0.398150   0.086080  0.669278
# 233  0.396148  0.104954   0.769315  0.954455
#
# [234 rows x 4 columns]

# %%
#change the columns name
ndf.columns=list("ABCD")

# %%
ndf
# Out:
#             A         B          C         D
# 0          56  0.077906   0.726501  0.821850
# 1    0.839622  0.847196  56.650000  0.091369
# 2    0.166745  0.904992   0.119703  0.984185
# 3    0.481827  0.013274   0.562768  0.928823
# 4    0.990852  0.148449   0.978093  0.744958
# ..        ...       ...        ...       ...
# 229  0.209921  0.955497   0.141425  0.671245
# 230  0.778924  0.642971   0.188551  0.590218
# 231  0.458433  0.165374   0.754682  0.516811
# 232  0.289907  0.398150   0.086080  0.669278
# 233  0.396148  0.104954   0.769315  0.954455
#
# [234 rows x 4 columns]

# %%
#add col if you make 
ndf.loc[0,0]=52

# %%
ndf
# Out:
#             A         B          C         D     0
# 0          56  0.077906   0.726501  0.821850  52.0
# 1    0.839622  0.847196  56.650000  0.091369   NaN
# 2    0.166745  0.904992   0.119703  0.984185   NaN
# 3    0.481827  0.013274   0.562768  0.928823   NaN
# 4    0.990852  0.148449   0.978093  0.744958   NaN
# ..        ...       ...        ...       ...   ...
# 229  0.209921  0.955497   0.141425  0.671245   NaN
# 230  0.778924  0.642971   0.188551  0.590218   NaN
# 231  0.458433  0.165374   0.754682  0.516811   NaN
# 232  0.289907  0.398150   0.086080  0.669278   NaN
# 233  0.396148  0.104954   0.769315  0.954455   NaN
#
# [234 rows x 5 columns]

# %%
# to drop any series
# it will return only copy no effect on df
ndf.drop(0, axis=1)
# Out:
#             A         B          C         D
# 0          56  0.077906   0.726501  0.821850
# 1    0.839622  0.847196  56.650000  0.091369
# 2    0.166745  0.904992   0.119703  0.984185
# 3    0.481827  0.013274   0.562768  0.928823
# 4    0.990852  0.148449   0.978093  0.744958
# ..        ...       ...        ...       ...
# 229  0.209921  0.955497   0.141425  0.671245
# 230  0.778924  0.642971   0.188551  0.590218
# 231  0.458433  0.165374   0.754682  0.516811
# 232  0.289907  0.398150   0.086080  0.669278
# 233  0.396148  0.104954   0.769315  0.954455
#
# [234 rows x 4 columns]

# %%
# to get part
ndf.loc[[1,2],['B','C']]
# Out:
#           B          C
# 1  0.847196  56.650000
# 2  0.904992   0.119703

# %%
#to get only rrow or col

ndf.loc[:,['B','D']]
# Out:
#             B         D
# 0    0.077906  0.821850
# 1    0.847196  0.091369
# 2    0.904992  0.984185
# 3    0.013274  0.928823
# 4    0.148449  0.744958
# ..        ...       ...
# 229  0.955497  0.671245
# 230  0.642971  0.590218
# 231  0.165374  0.516811
# 232  0.398150  0.669278
# 233  0.104954  0.954455
#
# [234 rows x 2 columns]

# %%
#conditional row
ndf.loc[(ndf['C']>0.2)]
# Out:
#             A         B          C         D     0
# 0          56  0.077906   0.726501  0.821850  52.0
# 1    0.839622  0.847196  56.650000  0.091369   NaN
# 3    0.481827  0.013274   0.562768  0.928823   NaN
# 4    0.990852  0.148449   0.978093  0.744958   NaN
# 5    0.721355  0.837800   0.386597  0.814635   NaN
# ..        ...       ...        ...       ...   ...
# 225  0.742042  0.709590   0.254754  0.559454   NaN
# 227   0.93889  0.757868   0.539230  0.370963   NaN
# 228  0.868826  0.938833   0.430220  0.710817   NaN
# 231  0.458433  0.165374   0.754682  0.516811   NaN
# 233  0.396148  0.104954   0.769315  0.954455   NaN
#
# [182 rows x 5 columns]

# %%
#to show effect on df of drop use
ndf=ndf.drop(['A'],axis=1)

# %%
ndf=ndf.drop([0],axis=1)

# %%
ndf
# Out:
#             B          C         D
# 0    0.077906   0.726501  0.821850
# 1    0.847196  56.650000  0.091369
# 2    0.904992   0.119703  0.984185
# 3    0.013274   0.562768  0.928823
# 4    0.148449   0.978093  0.744958
# ..        ...        ...       ...
# 229  0.955497   0.141425  0.671245
# 230  0.642971   0.188551  0.590218
# 231  0.165374   0.754682  0.516811
# 232  0.398150   0.086080  0.669278
# 233  0.104954   0.769315  0.954455
#
# [234 rows x 3 columns]

# %%
ndf.drop([2],axis=0, inplace=True)

# %%
ndf
# Out:
#             B         C         D
# 0    0.077906  0.726501  0.821850
# 3    0.013274  0.562768  0.928823
# 4    0.148449  0.978093  0.744958
# 5    0.837800  0.386597  0.814635
# 6    0.682897  0.281903  0.476947
# ..        ...       ...       ...
# 229  0.955497  0.141425  0.671245
# 230  0.642971  0.188551  0.590218
# 231  0.165374  0.754682  0.516811
# 232  0.398150  0.086080  0.669278
# 233  0.104954  0.769315  0.954455
#
# [232 rows x 3 columns]

# %%
# to reset index
#use drop=true to drop index col
ndf.reset_index(drop=True,inplace=True)

# %%
ndf
# Out:
#             B         C         D
# 0    0.077906  0.726501  0.821850
# 1    0.013274  0.562768  0.928823
# 2    0.148449  0.978093  0.744958
# 3    0.837800  0.386597  0.814635
# 4    0.682897  0.281903  0.476947
# ..        ...       ...       ...
# 227  0.955497  0.141425  0.671245
# 228  0.642971  0.188551  0.590218
# 229  0.165374  0.754682  0.516811
# 230  0.398150  0.086080  0.669278
# 231  0.104954  0.769315  0.954455
#
# [232 rows x 3 columns]
